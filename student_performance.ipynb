# %%
#to import pandas library
import pandas as pd
#to load excel file from github repository
df=pd.read_excel("https://github.com/Jk-rowling/dataset/raw/refs/heads/main/datasheet.xlsx")
df
# Out:
#     Student ID              Name  Gender Date of Birth  Class Section  \
# 0        S0001    Jeffrey Duarte    Male    2005-09-07      8       D
# 1        S0002        Jacob Cain    Male    2007-03-17     10       C
# 2        S0003       Lisa Garcia    Male    2007-06-22     10       C
# 3        S0004     Jennifer Gray  Female    2007-05-08      9       C
# 4        S0005        Jason Tran  Female    2010-12-23     12       C
# ..         ...               ...     ...           ...    ...     ...
# 521      S0496  Michael Sheppard  Female    2008-03-21     10       B
# 522      S0497     Sonya Ramirez    Male    2007-11-28     10       B
# 523      S0498    Jessica Garcia    Male    2009-02-21     12       B
# 524      S0499     Kayla Johnson    Male    2005-11-08     11       D
# 525      S0500      Ashley Smith    Male    2007-08-14      9       D
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# ...

# %%
# Displaying the information regarding the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student ID        526 non-null    object
#  1   Name              526 non-null    object
#  2   Gender            526 non-null    object
#  3   Date of Birth     526 non-null    datetime64[ns]
#  4   Class             526 non-null    int64
#  5   Section           526 non-null    object
#  6   Roll Number       526 non-null    int64
#  7   Marks (Hindi)     526 non-null    int64
#  8   Marks (English)   526 non-null    int64
#  9   Marks (Maths)     526 non-null    int64
#  10  Marks (Science)   526 non-null    int64
#  11  Marks (Computer)  526 non-null    int64
#  12  Total Marks       526 non-null    int64
#  13  Percentage        526 non-null    float64
#  14  Grade             526 non-null    object
#  15  Division          526 non-null    object
# ...

# %%
# storing all the duplicate values in duplicates_of_df
duplicates_of_df=df[df.duplicated()]
#if there are no duplicates, then it will print nothing
print(duplicates_of_df)
# Out:
#     Student ID                Name  Gender Date of Birth  Class Section  \
# 99       S0040        Damon Medina  Female    2006-06-27      9       D
# 100      S0041        Kelly Decker  Female    2007-06-18     11       C
# 101      S0042       Anne Gonzales    Male    2005-11-12     11       D
# 102      S0043           Evan Diaz  Female    2008-09-28      8       D
# 103      S0044       Brooke Martin    Male    2006-07-12     12       B
# 104      S0045         Andrew Rice  Female    2006-01-05     11       A
# 105      S0046       Linda Schmidt    Male    2010-04-20     11       B
# 106      S0047      Matthew Bowers    Male    2010-12-04     11       D
# 107      S0048    Clifford Collins    Male    2010-11-14     12       A
# 108      S0049        Meghan Roach  Female    2010-04-14      9       D
# 388      S0250      Curtis Stewart    Male    2005-07-15      8       D
# 389      S0251        Brett Barton  Female    2008-09-17     10       B
# ...

# %%
#to remove all duplicates
df1=df.drop_duplicates()
sdf1
# Out:
#     Student ID              Name  Gender Date of Birth  Class Section  \
# 0        S0001    Jeffrey Duarte    Male    2005-09-07      8       D
# 1        S0002        Jacob Cain    Male    2007-03-17     10       C
# 2        S0003       Lisa Garcia    Male    2007-06-22     10       C
# 3        S0004     Jennifer Gray  Female    2007-05-08      9       C
# 4        S0005        Jason Tran  Female    2010-12-23     12       C
# ..         ...               ...     ...           ...    ...     ...
# 521      S0496  Michael Sheppard  Female    2008-03-21     10       B
# 522      S0497     Sonya Ramirez    Male    2007-11-28     10       B
# 523      S0498    Jessica Garcia    Male    2009-02-21     12       B
# 524      S0499     Kayla Johnson    Male    2005-11-08     11       D
# 525      S0500      Ashley Smith    Male    2007-08-14      9       D
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# ...

# %%
# printing the number of row x columns
print("The number of Rows and Columns in the dataset")
df1.shape
# Out:
# The number of Rows and Columns in the dataset
# (500, 16)

# %%
# Printing only the number of Rows
print("The number of Rows in the Dataset")
df1.shape[0]
# Out:
# The number of Rows in the Dataset
# 500

# %%
# Printing only the number of Columns
print("The number of Columns in the Dataset")
df1.shape[1]
# Out:
# The number of Columns in the Dataset
# 16

# %%
# To print the top 15 rows of the dataset
df1.head(15)
# Out:
#    Student ID              Name  Gender Date of Birth  Class Section  \
# 0       S0001    Jeffrey Duarte    Male    2005-09-07      8       D
# 1       S0002        Jacob Cain    Male    2007-03-17     10       C
# 2       S0003       Lisa Garcia    Male    2007-06-22     10       C
# 3       S0004     Jennifer Gray  Female    2007-05-08      9       C
# 4       S0005        Jason Tran  Female    2010-12-23     12       C
# 5       S0006        Eileen Lee    Male    2010-05-21     12       A
# 6       S0007    Joshua Krueger    Male    2010-02-28     10       C
# 7       S0008     Tyler Simmons    Male    2007-09-23      8       B
# 8       S0009     Amber Wheeler  Female    2006-04-23      9       B
# 9       S0010        Paul Bryan  Female    2009-04-17     11       B
# 10      S0011   Andrea Thornton  Female    2010-03-21      8       A
# 11      S0012  Courtney Roberts  Female    2006-05-04      9       D
# 12      S0013    Joseph Rodgers  Female    2009-06-15     12       B
# ...

# %%
# To print the bottom 15 rows of the dataset
df1.tail(15)
# Out:
#     Student ID              Name  Gender Date of Birth  Class Section  \
# 511      S0486    Maxwell Mendez    Male    2006-06-16     12       D
# 512      S0487    Sarah Chandler    Male    2008-09-08      8       A
# 513      S0488         Jesse Lee  Female    2007-01-21      8       C
# 514      S0489     William Brown  Female    2006-10-05      9       B
# 515      S0490      Tammy Graham  Female    2007-04-10      9       D
# 516      S0491       Bryce Scott  Female    2010-03-27     12       D
# 517      S0492     Daniel Palmer    Male    2008-04-08     11       D
# 518      S0493        Joe Krause    Male    2005-12-17      8       D
# 519      S0494    Dylan Martinez    Male    2005-01-14      9       C
# 520      S0495        Olivia Cox    Male    2009-08-20      8       A
# 521      S0496  Michael Sheppard  Female    2008-03-21     10       B
# 522      S0497     Sonya Ramirez    Male    2007-11-28     10       B
# ...

# %%
# To print any random 10 rows
df1.sample(10)
# Out:
#     Student ID              Name  Gender Date of Birth  Class Section  \
# 192      S0183     Joseph Harris  Female    2008-05-02     10       D
# 173      S0164     Pamela Miller    Male    2008-11-10      8       B
# 324      S0315    Terri Mcdonald    Male    2010-04-27     11       C
# 367      S0358   Anthony Johnson  Female    2005-03-17      8       A
# 469      S0444   William Schmidt    Male    2006-05-01      8       C
# 458      S0439  Stephanie Walker  Female    2008-02-10      9       C
# 125      S0116   Kimberly Miller  Female    2010-12-07     10       A
# 440      S0421    Shannon Church  Female    2005-10-08     11       C
# 412      S0393     Timothy Casey    Male    2010-06-06     10       A
# 466      S0441     Frank Sanchez  Female    2006-02-09     12       C
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# 192           26             99               95             74
# 173           22             71               74             91
# ...

# %%
# To print a specific coloumn (Division)
print(df1['Division'])
# Out:
# 0      Second
# 1       First
# 2      Second
# 3      Second
# 4      Second
#         ...
# 521     Third
# 522    Second
# 523    Second
# 524     Third
# 525     First
# Name: Division, Length: 500, dtype: object

# %%
# To print the top 20 rows from a specific Column
df1['Percentage'].head(10)
# Out:
# 0    62.4
# 1    81.6
# 2    63.6
# 3    60.4
# 4    64.8
# 5    71.0
# 6    62.4
# 7    65.2
# 8    61.2
# 9    90.0
# Name: Percentage, dtype: float64

# %%
#to display top 10 records of Marks (Hindi)
df1['Marks (Maths)'].head(10)
# Out:
# 0    71
# 1    67
# 2    60
# 3    59
# 4    38
# 5    52
# 6    59
# 7    83
# 8    35
# 9    91
# Name: Marks (Maths), dtype: int64

# %%
#to sort the table based on a column
df1.sort_values(by=['Total Marks'])
# Out:
#     Student ID               Name  Gender Date of Birth  Class Section  \
# 204      S0195        Leon Lawson    Male    2009-05-12      8       B
# 308      S0299     Denise Gregory    Male    2009-04-24     10       A
# 309      S0300     Logan Peterson  Female    2008-06-09     11       A
# 20       S0021    Veronica Taylor  Female    2008-08-02      8       B
# 330      S0321        Mariah Reid    Male    2007-05-27      8       C
# ..         ...                ...     ...           ...    ...     ...
# 87       S0088        Carla Stout  Female    2010-10-23     10       B
# 38       S0039         James Bray  Female    2005-02-21      9       B
# 265      S0256  Patrick Rodriguez  Female    2009-08-04      8       C
# 168      S0159         Linda Luna  Female    2010-08-04     12       C
# 9        S0010         Paul Bryan  Female    2009-04-17     11       B
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# ...

# %%
# To sort the dataset based on multiple column
df1.sort_values(by=['Grade','Division'])
# Out:
#     Student ID              Name  Gender Date of Birth  Class Section  \
# 9        S0010        Paul Bryan  Female    2009-04-17     11       B
# 1        S0002        Jacob Cain    Male    2007-03-17     10       C
# 23       S0024      Mallory Cruz  Female    2010-05-06      8       B
# 24       S0025      Erica Guerra  Female    2007-10-10     11       B
# 26       S0027      Tony Griffin    Male    2007-09-10     11       B
# ..         ...               ...     ...           ...    ...     ...
# 520      S0495        Olivia Cox    Male    2009-08-20      8       A
# 521      S0496  Michael Sheppard  Female    2008-03-21     10       B
# 524      S0499     Kayla Johnson    Male    2005-11-08     11       D
# 204      S0195       Leon Lawson    Male    2009-05-12      8       B
# 308      S0299    Denise Gregory    Male    2009-04-24     10       A
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# ...

# %%
#statistical analysis of dataframe
df1.describe()
# Out:
#             Class  Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# count  500.000000   500.000000     500.000000       500.000000     500.000000
# mean    10.068000    26.686000      64.256000        65.066000      63.064000
# std      1.446222    14.736136      20.397318        20.395824      20.293041
# min      8.000000     1.000000      30.000000        30.000000      30.000000
# 25%      9.000000    13.000000      46.000000        47.000000      45.750000
# 50%     10.000000    28.000000      64.000000        65.000000      63.000000
# 75%     11.000000    40.000000      81.250000        82.000000      79.000000
# max     12.000000    50.000000     100.000000       100.000000     100.000000
#
#        Marks (Science)  Marks (Computer)  Total Marks  Percentage
# count       500.000000        500.000000   500.000000  500.000000
# mean         64.232000         64.862000   321.480000   64.296000
# std          20.097213         21.056822    47.992167    9.598433
# ...

# %%
#statistical analysis of dataframe for non numeric columns
df1.describe(include=object)
# Out:
#        Student ID         Name Gender Section Grade Division
# count         500          500    500     500   500      500
# unique        500          499      2       4     5        4
# top         S0001  Jill Garcia   Male       C     C   Second
# freq            1            2    254     132   275      275

# %%
#to count the unique values from column 'section'
print("The Number of times each Unique value is repeated in Section")
print(df1['Section'].value_counts())
# Out:
# The Number of times each Unique value is repeated in Section
# C    132
# D    126
# B    123
# A    119
# Name: Section, dtype: int64

# %%
print("The Number of times each Unique value is repeated in Grade")
print(df1['Grade'].value_counts())
# Out:
# The Number of times each Unique value is repeated in Grade
# C    275
# D    154
# B     68
# F      2
# A      1
# Name: Grade, dtype: int64

# %%
# To print the lowest number of Percentage
print("The Lowest number of percentage:")
print(df1['Percentage'].min())
# Out:
# The Lowest number of percentage:
# 35.8

# %%
# To print the Highest number of Percentage
print("The Highest number of percentage:")
print(df1['Percentage'].max())
# Out:
# The Highest number of percentage:
# 90.0

# %%
#correlation between Marks (Hindi) and Percentage
df1['Total Marks'].corr(df1['Percentage'])
# Out:
# 1.0

# %%
#top 5 performers in English subject
df1.nlargest(5,'Marks (English)')
# Out:
#     Student ID             Name  Gender Date of Birth  Class Section  \
# 9        S0010       Paul Bryan  Female    2009-04-17     11       B
# 59       S0060    Dalton Wilson  Female    2009-11-24      9       C
# 69       S0070   Michael Garcia  Female    2006-08-26     12       D
# 97       S0098   Robert Woodard    Male    2005-05-16      9       B
# 180      S0171  Patricia Baxter  Female    2008-05-16     12       A
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# 9             31             79              100             91
# 59            43             54              100             90
# 69            12             39              100             53
# 97            43             97              100             82
# 180            1             37              100             85
#
#      Marks (Science)  Marks (Computer)  Total Marks  Percentage Grade Division
# 9                 99                81          450        90.0     A    First
# ...

# %%
#bottom 5 performers in English subject
df1.nsmallest(5,'Marks (English)')
# Out:
#     Student ID           Name  Gender Date of Birth  Class Section  \
# 15       S0016  Deborah Price  Female    2007-12-25      8       C
# 22       S0023   Devon Thomas  Female    2008-11-06     12       A
# 28       S0029  Jade Morrison  Female    2010-03-12     10       A
# 160      S0151     Lori Knapp    Male    2007-10-11      9       D
# 189      S0180    Susan Bowen  Female    2009-07-23     12       D
#
#      Roll Number  Marks (Hindi)  Marks (English)  Marks (Maths)  \
# 15            27             81               30             36
# 22            44             32               30             68
# 28            24             43               30             45
# 160            3             61               30             62
# 189           42             44               30             32
#
#      Marks (Science)  Marks (Computer)  Total Marks  Percentage Grade Division
# 15                70                97          314        62.8     C   Second
# ...

# %%
#importing matplotlip pyplot library
import matplotlib.pyplot as plt
